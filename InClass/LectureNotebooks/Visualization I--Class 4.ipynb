# %%
import warnings
warnings.filterwarnings('ignore')


import pandas as pd
import numpy as np
from plotnine import *
from plotnine.data import mtcars

# %matplotlib inline

# %% [markdown]
# # INTRO to GG

# %%
(ggplot(mtcars, aes(x = "wt", y = "mpg")) + geom_point())
# Out:
# <ggplot: (305184418)>

# %%
(ggplot(mtcars, aes(x = "wt", y = "mpg")) +
 geom_point() + 
stat_smooth(method = "lm"))
# Out:
# <ggplot: (305318927)>

# %%
(ggplot(mtcars, aes(x = "wt", y = "mpg")) +
 geom_point() + 
stat_smooth(method = "lm") +
facet_wrap("~gear"))
# Out:
# <ggplot: (305310917)>

# %%
(ggplot(mtcars, aes(x = "wt", y = "mpg", color = "factor(gear)")) +
 geom_point() + 
stat_smooth(method = "lm") +
facet_wrap("~gear"))
# Out:
# <ggplot: (305434509)>

# %%
penguin = pd.read_csv("https://raw.githubusercontent.com/cmparlettpelleriti/CPSC392ParlettPelleriti/master/Data/penguins.csv")
print(penguin.head())
# Out:
#    Unnamed: 0 species     island  bill_length_mm  bill_depth_mm  \
# 0           0  Adelie  Torgersen            39.1           18.7
# 1           1  Adelie  Torgersen            39.5           17.4
# 2           2  Adelie  Torgersen            40.3           18.0
# 3           3  Adelie  Torgersen             NaN            NaN
# 4           4  Adelie  Torgersen            36.7           19.3
#
#    flipper_length_mm  body_mass_g     sex  year
# 0              181.0       3750.0    male  2007
# 1              186.0       3800.0  female  2007
# 2              195.0       3250.0  female  2007
# 3                NaN          NaN     NaN  2007
# 4              193.0       3450.0  female  2007

# %% [markdown]
# # GG Basic Steps
# ## 1. Tell GG WHAT data you want to use

# %%
(ggplot(penguin, aes(x = "bill_length_mm",
                    y = "bill_depth_mm",
                    color = "species")))
# Out:
# <ggplot: (-9223372036549224995)>

# %% [markdown]
# ## 2. Tell GG HOW you want the data to show up

# %%
(ggplot(penguin, aes(x = "bill_length_mm",
                    y = "bill_depth_mm",
                    color = "species")) + 
geom_point())
# Out:
# <ggplot: (305396337)>

# %% [markdown]
# ## 1. Tell GG WHAT data you want to use

# %%
(ggplot(penguin, aes( x = "body_mass_g")))
# Out:
# <ggplot: (-9223372036549225058)>

# %% [markdown]
# ## 2. Tell GG HOW you want the data to show up

# %%
(ggplot(penguin, aes( x = "body_mass_g")) + 
geom_histogram())
# Out:
# <ggplot: (-9223372036549392682)>

# %% [markdown]
# ## 1. Tell GG WHAT data you want to use

# %%
(ggplot(penguin, aes(x = "species")))
# Out:
# <ggplot: (305193508)>

# %% [markdown]
# ## 2. Tell GG HOW you want the data to show up

# %%
(ggplot(penguin, aes(x = "species")) +
geom_bar())
# Out:
# <ggplot: (-9223372036549407530)>

# %% [markdown]
# ## 1. Tell GG WHAT data you want to use

# %%
(ggplot(penguin, aes(x = "species", y = "bill_length_mm")))
# Out:
# <ggplot: (-9223372036549172494)>

# %% [markdown]
# ## 2. Tell GG HOW you want the data to show up

# %%
(ggplot(penguin, aes(x = "species", y = "bill_length_mm")) + geom_boxplot())
# Out:
# <ggplot: (-9223372036549464951)>

# %% [markdown]
# ## 3. Extras

# %%
(ggplot(penguin, aes(x = "species", y = "bill_length_mm", fill = "species")) + geom_boxplot())
# Out:
# <ggplot: (305651923)>

# %%
(ggplot(penguin, aes(x = "species", y = "bill_length_mm", fill = "species")) + geom_boxplot() + theme_minimal())
# Out:
# <ggplot: (305647515)>

# %%
(ggplot(penguin, aes(x = "species", y = "bill_length_mm", fill = "species")) + geom_boxplot() +
 geom_point() + 
 theme_minimal())
# Out:
# <ggplot: (-9223372036549052412)>

# %%
(ggplot(penguin, aes(x = "species", y = "bill_length_mm")) + geom_boxplot(aes(fill = "species")) +
 geom_point() + 
 theme_minimal())
# Out:
# <ggplot: (305718834)>

# %% [markdown]
# # Prepping Data for Barcharts

# %%
(ggplot(penguin, aes(x = "species", y = "body_mass_g", fill = "species")) +
stat_summary(fun_data = "mean_sdl", geom = "bar"))
# Out:
# <ggplot: (305768498)>

# %%
(ggplot(penguin, aes( x = "species", y = "body_mass_g", fill = "species")) +
 stat_summary(fun_data = "mean_sdl", geom = "bar")+
 labs(x = "Species", y = "Body Mass (g)") + 
 ggtitle("Penguin Body Mass by Species") +
 theme_minimal() +
 theme(panel_grid_major_x = element_blank(),
     panel_grid_minor_x = element_blank(),
      panel_grid_minor_y = element_blank(),
      legend_position = "none"))
# Out:
# <ggplot: (-9223372036548966070)>

# %% [markdown]
# # Let's Try to explore a new data set using Visualization!

# %%
cereal = pd.read_csv("https://raw.githubusercontent.com/reisanar/datasets/master/Cereals.csv")
cereal.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100%_Bran   N    C        70        4    1     130   10.0
# 1          100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4             Almond_Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0        25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0         0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0        25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0        25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN        25      3     1.0  0.75  34.384843

# %%
(ggplot(cereal, aes(x = "mfr")) + geom_bar(aes(fill = "mfr")) + theme_bw())
# Out:
# <ggplot: (305892374)>

# %%
#facet wrap/grid
(ggplot(cereal, aes( x = "protein", y = "sugars")) + geom_point() +
facet_wrap("~mfr") + theme_bw())
# Out:
# <ggplot: (305874075)>
